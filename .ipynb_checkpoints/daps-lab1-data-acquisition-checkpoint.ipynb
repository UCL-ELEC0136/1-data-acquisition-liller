# %% [markdown]
# # Task 1: Small case scenario of dataset analysis

# %% [markdown]
# ## 1.1 - Create a dataset (The Tate Collection)
# As a first example, we will create our own small dataset. In particular, the dataset will consist of 10 artists which are present in the Tate Collection along with the corresponding year of birth, year of death, biological gender and number of artworks.
#
# |          Name         | Gender |   Year_Birth  |   Year_Death  | N_works |
# |-----------------------|--------|---------------|---------------|---------|
# |     Beuys, Joseph     |  Male  |      1921	 |      1986     |   588   |
# |    Constable, John    |  Male  |      1776	 |      1837	 |   249   |
# |   Daniell, William    |  Male  |      1769	 |      1837	 |   612   |
# |   Forbes, Elizabeth   | Female |      1859	 |      1912	 |   120   |
# |     Flaxman, John     |  Male  |      1755	 |      1826	 |   287   |
# |    Phillips, Thomas   |  Male  |      1770	 |      1845	 |   274   |
# | Paolozzi, Sir Eduardo |  Male  |      1924	 |      2005	 |   385   |
# |     Schendel, Mira    | Female |      1919	 |      1988	 |    3    |
# |    Turner, William    |  Male  |      1775	 |      1851	 |  1861   |
# |      Warhol, Andy     |  Male  |      1928	 |      1987	 |   272   |

# %% [markdown]
# **_[TO DO]_**: Let's create a DataFrame named **TateDataset** with the information showed in the above table.
#
# **Note:** You can create arrays for each column and then build the DataFrame.
# Remember to import the required libraries!

# %%
# @title Imports
import numpy as np
import pandas as pd
pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)

# %%
### TODO DataFrame是一个表格型的数据结构

dataset = {
    'Name':['Beuys, Joseph','Constable, John','Daniell, William', 'Forbes, Elizabeth','Flaxman, John','Phillips, Thomas','Paolozzi, Sir Eduardo','Schendel, Mira','Turner, William','Warhol, Andy'],
    'Gender':['Male','Male','Male','Female','Male','Male','Male','Female','Male','Male'],
    'Year_Birth':[1921,1776,1769,1859,1755,1770,1924,1919,1775,1928],
    'Year_Death':[1986,1837,1837,1912,1826,1845,2005,1988,1851,1987],
    'N_works':[588,249,612,120,287,274,385,3,1861,272]
}
# print(dataset)
tate_dataset = pd.DataFrame(data=dataset)
tate_dataset
# Out:
#                     Name  Gender  Year_Birth  Year_Death  N_works
# 0          Beuys, Joseph    Male        1921        1986      588
# 1        Constable, John    Male        1776        1837      249
# 2       Daniell, William    Male        1769        1837      612
# 3      Forbes, Elizabeth  Female        1859        1912      120
# 4          Flaxman, John    Male        1755        1826      287
# 5       Phillips, Thomas    Male        1770        1845      274
# 6  Paolozzi, Sir Eduardo    Male        1924        2005      385
# 7         Schendel, Mira  Female        1919        1988        3
# 8        Turner, William    Male        1775        1851     1861
# 9           Warhol, Andy    Male        1928        1987      272

# %% [markdown]
# ## 1.2 - Data Acquisition (local file)
#
# Data acquisition is a process of loading and reading data from various sources. We will learn how to export and read data from a local file in different format using  **Pandas** package.
#
# A file format is a standardised way in which information is encoded to be stored in a file. Some examples of file formats are: CSV, XLSX, and PKL.
#
# Let's practice with some examples.
#
# ### .CSV - Comma Separated Values
#
# CSV is one of the most popular spreadsheet file format. In this kind of file, data is stored in cells. Each cell is organized in rows and columns. A column in the spreadsheet file can have different types.
#
# Let us look at how to create a CSV file. We can export a DataFrame with the Pandas function `to_csv()`. The file will be saved in the same location of this notebook unless specified otherwise. We can name the file **TateData.csv**.
#
# **Note:** Once you have run the following cell, check the output file .

# %%
# without index column
tate_dataset.to_csv('tate_dataset.csv', index=False, header=True)

# %% [markdown]
# To pull in the csv file, we will use the Pandas function `read_csv()`. We will import the previous file in a new DataFrame.
#
# **Note:**  Depending on where you save your notebooks, you may need to modify the location below.

# %%
tate_1 = pd.read_csv('tate_dataset.csv')
tate_1
# Out:
#                     Name  Gender  Year_Birth  Year_Death  N_works
# 0          Beuys, Joseph    Male        1921        1986      588
# 1        Constable, John    Male        1776        1837      249
# 2       Daniell, William    Male        1769        1837      612
# 3      Forbes, Elizabeth  Female        1859        1912      120
# 4          Flaxman, John    Male        1755        1826      287
# 5       Phillips, Thomas    Male        1770        1845      274
# 6  Paolozzi, Sir Eduardo    Male        1924        2005      385
# 7         Schendel, Mira  Female        1919        1988        3
# 8        Turner, William    Male        1775        1851     1861
# 9           Warhol, Andy    Male        1928        1987      272

# %% [markdown]
# When we create the .CSV file, the only parameter we have used is **index**.
#
# **[TO DO]** What happens if we set the *index* parameter to True? And if you set also the parameter **header** to False?
# Try by yourself.

# %%
### TODO
tate_dataset.to_csv('tate_dataset_01.csv', index=True, header=True)

# %%
tate_dataset.to_csv('tate_dataset_02.csv', index=True, header=False)

# %% [markdown]
# Delete the csv file now that we are done using it.

# %% [markdown]
# ### pickle — Python object serialization
#
# This data format is Python-specific. This has the advantage that there are no restrictions imposed by external standards; however it means that non-Python programs may not be able to reconstruct pickled Python objects.

# %%
# 序列化课将变量转为字节存储在本地，避免程序结束后在内存中释放.
#将Dataframe序列化
import pickle

tate_dataset.to_pickle('tate_dataset.pkl')

# %%
tate_2 = pd.read_pickle('tate_dataset.pkl')
tate_2
# Out:
#                     Name  Gender  Year_Birth  Year_Death  N_works
# 0          Beuys, Joseph    Male        1921        1986      588
# 1        Constable, John    Male        1776        1837      249
# 2       Daniell, William    Male        1769        1837      612
# 3      Forbes, Elizabeth  Female        1859        1912      120
# 4          Flaxman, John    Male        1755        1826      287
# 5       Phillips, Thomas    Male        1770        1845      274
# 6  Paolozzi, Sir Eduardo    Male        1924        2005      385
# 7         Schendel, Mira  Female        1919        1988        3
# 8        Turner, William    Male        1775        1851     1861
# 9           Warhol, Andy    Male        1928        1987      272

# %% [markdown]
# ## 1.3 - Look at the data
#
# Now we will simply have a look at the data and make sure it is clean.
#
# ### Data type
# Let's check the data type of the imported variables and the original DataFrame.

# %%
# Check data type of the columns for Tate_1
tate_1.dtypes
# Out:
# Name          object
# Gender        object
# Year_Birth     int64
# Year_Death     int64
# N_works        int64
# dtype: object

# %%
# Check data type of the columns for TateDataset
tate_dataset.dtypes
# tate_dataset.columns
# Out:
# Name          object
# Gender        object
# Year_Birth     int64
# Year_Death     int64
# N_works        int64
# dtype: object

# %% [markdown]
# We can also display the values of a single column and check their data type as follow:

# %%
tate_dataset['Gender']
# Out:
# 0      Male
# 1      Male
# 2      Male
# 3    Female
# 4      Male
# 5      Male
# 6      Male
# 7    Female
# 8      Male
# 9      Male
# Name: Gender, dtype: object

# %% [markdown]
# # Task 2: Application Programming Interfaces (APIs)

# %% [markdown]
# ## 2.1 - Downloading climate data from the Internet
#
# We will now explore real world data, namely a dataset of climate information of 5 cities in Denmark between 1980-2018. The original raw-data was originally obtained from [National Climatic Data Center (NCDC)](https://www7.ncdc.noaa.gov/CDO/cdoselect.cmd).
#
# In particular, the selected cities in Denmark are:
# - Aalborg,
# - Aarhus,
# - Esbjerg,
# - Odense.
# - Roskilde
#
# In the following, we will download the dataset using an API instead of loading a local source file.
#
# ### What is an API?
# Application Programming Interface (API) is a communication protocol between the user and the server (i.e., web server) that enables transmittion of data. The user making a request to an API server can download the desidered resources.
#
# ### How to make a request in python?
# There are many different way to request data.
# In the following, we will use the package **urllib** that collects several modules for working with URLs.
#
# In particular, [urlib.request](https://docs.python.org/3/library/urllib.request.html#module-urllib.request) is a module for opening and reading URLs.

# %% [markdown]
# ### - Download climate data
#
#
# The following functions allow to download and store the dataset in a specific folder.
#
# How to use:
#
# - Set the source (i.e., URL) of the desidered dataset in `data_url`.
# - Set the `data_dir` variable with the local directory where to store the data.
# - Call `download_and_extract()` to download the dataset if it is not already located in the given data_dir.
# - Load the data in the interactive Python notebook so ic can be used in your scripts (you can use `load_original_data()`).

# %%
#@title Functions to download data 
########################################################################
#
# This file is a partially modified version of one of the TensorFlow Tutorials available at:
#
# https://github.com/Hvass-Labs/TensorFlow-Tutorials
#
# Published under the MIT License. See the file LICENSE for details.
#
# Copyright 2018 by Magnus Erik Hvass Pedersen
#
########################################################################

import sys
import os
import urllib.request
import tarfile
import zipfile



def _print_download_progress(count, block_size, total_size):
    """
    Function used for printing the download progress.
    Used as a call-back function in maybe_download_and_extract().
    """

    # Percentage completion.
    pct_complete = float(count * block_size) / total_size

    # Limit it because rounding errors may cause it to exceed 100%.
    pct_complete = min(1.0, pct_complete)

    # Status-message. Note the \r which means the line should overwrite itself.
    msg = "\r- Download progress: {0:.1%}".format(pct_complete)

    # Print it.
    sys.stdout.write(msg)
#     将缓冲区的数据输出
    sys.stdout.flush()


def download(base_url, filename, download_dir):
    """
    Download the given file if it does not already exist in the download_dir.
    :param base_url: The internet URL without the filename.
    :param filename: The filename that will be added to the base_url.
    :param download_dir: Local directory for storing the file.
    """

    # Path for local file. 将多个路径组合后返回
    save_path = os.path.join(download_dir, filename)

    # Check if the file already exists, otherwise we need to download it now.
    if not os.path.exists(save_path):
        # Check if the download directory exists, otherwise create it.
        if not os.path.exists(download_dir):
            os.makedirs(download_dir)

        print("Downloading", filename, "...")

        # Download the file from the internet.
        url = base_url + filename
        file_path, _ = urllib.request.urlretrieve(url=url,
                                                  filename=save_path,
                                                  reporthook=_print_download_progress)

        print(" Done!")


def download_and_extract(url, download_dir):
    """
    Download and extract the data if it doesn't already exist.
    Assumes the url is a tar-ball file.
    :param url:
        Internet URL for the tar-file to download.
    :param download_dir:
        Directory where the downloaded file is saved.
    """

    # Filename for saving the file downloaded from the internet.
    # Use the filename from the URL and add it to the download_dir.
    filename = url.split('/')[-1]
    file_path = os.path.join(download_dir, filename)

    # Check if the file already exists.
    # If it exists then we assume it has also been extracted,
    # otherwise we need to download and extract it now.
    if not os.path.exists(file_path):
        # Check if the download directory exists, otherwise create it.
        if not os.path.exists(download_dir):
            os.makedirs(download_dir)

        # Download the file from the internet.
        file_path, _ = urllib.request.urlretrieve(url=url,
                                                  filename=file_path,
                                                  reporthook=_print_download_progress)

        print()
        print("Download finished. Extracting files.")

        if file_path.endswith(".zip"):
            # Unpack the zip-file.
            zipfile.ZipFile(file=file_path, mode="r").extractall(download_dir)
        elif file_path.endswith((".tar.gz", ".tgz")):
            # Unpack the tar-ball.
            tarfile.open(name=file_path, mode="r:gz").extractall(download_dir)

        print("Done.")
    else:
        print("Data has apparently already been downloaded and unpacked.")

# %% [markdown]
# First, we define where we want to download the dataset (you are free to choose another directory) and the URL of the dataset to be downloaded.

# %%
# Location of the dataset on the internet.
data_url = "https://github.com/Hvass-Labs/weather-denmark/raw/master/weather-denmark.tar.gz"

# Local directory where you want to download and save the dataset.
data_dir = "weather-data/"

# %% [markdown]
# Now, we can download the dataset into the chosen local directory

# %%
download_and_extract(url=data_url, download_dir=data_dir)
# Out:
# Data has apparently already been downloaded and unpacked.

# %% [markdown]
# **[TO DO]:** Check the local folder? In which format the dataset has been downloaded?
#
# **[TO DO]:** Select a format and load the dataset .

# %%
### TODO

# %%
### TODO
# load pickle format
weather_dataset = pd.read_pickle('weather-data/weather-denmark.pkl')
weather_dataset
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-149-9b7c88930080> in <module>
#       1 ### TODO
#       2 # load pickle format
# ----> 3 weather_dataset = pd.read_pickle('weather-data/weather-denmark.pkl')
#       4 weather_dataset
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/pickle.py in read_pickle(filepath_or_buffer, compression, storage_options)
#     199         compression=compression,
#     200         is_text=False,
# --> 201         storage_options=storage_options,
#     202     ) as handles:
#     203
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: 'weather-data/weather-denmark.pkl'

# %%
# f = open('weather-data/weather-denmark.pkl','rb')
# weather_dataset_frame = pickle.load(f)
# weather_dataset_frame

# %%
# load csv format
weather_dataset_01 = pd.read_csv('weather-data/weather-denmark.csv')
weather_dataset_01
# Out:
#              City             DateTime  Temp  Pressure  WindSpeed  WindDir
# 0         Aalborg  1980-03-01 00:00:00   5.0    1008.1       11.3    290.0
# 1         Aalborg  1980-03-01 00:20:00   4.0       NaN        9.2    270.0
# 2         Aalborg  1980-03-01 00:50:00   4.0       NaN        9.2    280.0
# 3         Aalborg  1980-03-01 01:20:00   4.0       NaN        9.2    280.0
# 4         Aalborg  1980-03-01 01:50:00   4.0       NaN        8.7    270.0
# ...           ...                  ...   ...       ...        ...      ...
# 2918145  Roskilde  2018-03-01 22:20:00  -5.0       NaN        5.1     70.0
# 2918146  Roskilde  2018-03-01 22:50:00  -5.0       NaN        4.1     70.0
# 2918147  Roskilde  2018-03-01 23:00:00  -5.3    1018.6        4.1     60.0
# 2918148  Roskilde  2018-03-01 23:20:00  -5.0       NaN        3.6     60.0
# 2918149  Roskilde  2018-03-01 23:50:00  -5.0       NaN        3.6     60.0
#
# [2918150 rows x 6 columns]

# %% [markdown]
# **More advanced solution for loading dataset**:
#
# In this case, the dataset was downloaded in two different formats.
# We can define the path where the files have been stored as follows:
# - **path_original_data_pickle( )** is the location of the original data in pickle format
# - **path_original_data_csv( )** is the location the original data in .csv

# %%
def path_original_data_pickle():
    return os.path.join(data_dir, "weather-denmark.pkl")

def path_original_data_csv():
    return os.path.join(data_dir, "weather-denmark.csv")

# %% [markdown]
# Now we can load the data in pickle format through the following function:

# %%
def load_original_data():
    return pd.read_pickle(path_original_data_pickle())

# %%
df = load_original_data()
df
# Out:
#                               Temp  Pressure  WindSpeed  WindDir
# City     DateTime
# Aalborg  1980-03-01 00:00:00   5.0    1008.1       11.3    290.0
#          1980-03-01 00:20:00   4.0       NaN        9.2    270.0
#          1980-03-01 00:50:00   4.0       NaN        9.2    280.0
#          1980-03-01 01:20:00   4.0       NaN        9.2    280.0
#          1980-03-01 01:50:00   4.0       NaN        8.7    270.0
# ...                            ...       ...        ...      ...
# Roskilde 2018-03-01 22:20:00  -5.0       NaN        5.1     70.0
#          2018-03-01 22:50:00  -5.0       NaN        4.1     70.0
#          2018-03-01 23:00:00  -5.3    1018.6        4.1     60.0
#          2018-03-01 23:20:00  -5.0       NaN        3.6     60.0
#          2018-03-01 23:50:00  -5.0       NaN        3.6     60.0
#
# [2918150 rows x 4 columns]

# %% [markdown]
# ### - Undestanding the data
#
# **_[TO DO]_**: Have a quick overview of the downloaded dataset.
# In particular, focus on:
#
# - Understanding the variables contained in the dataframe
# - Check the DateTime for 2 cities

# %%
### TODO check dataframe variables
df.dtypes
# Out:
# Temp         float64
# Pressure     float64
# WindSpeed    float64
# WindDir      float64
# dtype: object

# %%
##check index
df.index
# Out:
# MultiIndex([( 'Aalborg', '1980-03-01 00:00:00'),
#             ( 'Aalborg', '1980-03-01 00:20:00'),
#             ( 'Aalborg', '1980-03-01 00:50:00'),
#             ( 'Aalborg', '1980-03-01 01:20:00'),
#             ( 'Aalborg', '1980-03-01 01:50:00'),
#             ( 'Aalborg', '1980-03-01 02:20:00'),
#             ( 'Aalborg', '1980-03-01 03:00:00'),
#             ( 'Aalborg', '1980-03-01 03:20:00'),
#             ( 'Aalborg', '1980-03-01 04:00:00'),
#             ( 'Aalborg', '1980-03-01 04:01:00'),
#             ...
#             ('Roskilde', '2018-03-01 20:50:00'),
#             ('Roskilde', '2018-03-01 21:00:00'),
#             ('Roskilde', '2018-03-01 21:20:00'),
#             ('Roskilde', '2018-03-01 21:50:00'),
#             ('Roskilde', '2018-03-01 22:00:00'),
#             ('Roskilde', '2018-03-01 22:20:00'),
#             ('Roskilde', '2018-03-01 22:50:00'),
#             ('Roskilde', '2018-03-01 23:00:00'),
#             ('Roskilde', '2018-03-01 23:20:00'),
#             ('Roskilde', '2018-03-01 23:50:00')],
#            names=['City', 'DateTime'], length=2918150)

# %%
##check city 'Aalborg'
df.loc['Aalborg', '1980-03-01 00:00:00']
df.loc['Aalborg']
# Out:
#                      Temp  Pressure  WindSpeed  WindDir
# DateTime
# 1980-03-01 00:00:00   5.0    1008.1       11.3    290.0
# 1980-03-01 00:20:00   4.0       NaN        9.2    270.0
# 1980-03-01 00:50:00   4.0       NaN        9.2    280.0
# 1980-03-01 01:20:00   4.0       NaN        9.2    280.0
# 1980-03-01 01:50:00   4.0       NaN        8.7    270.0
# ...                   ...       ...        ...      ...
# 2018-03-01 22:50:00  -4.0       NaN        7.2     70.0
# 2018-03-01 23:00:00  -4.2    1022.5        7.2     70.0
# 2018-03-01 23:04:00  -4.0       NaN        6.7     70.0
# 2018-03-01 23:21:00  -4.0       NaN        6.7     70.0
# 2018-03-01 23:50:00  -4.0       NaN        6.2     70.0
#
# [759897 rows x 4 columns]

# %%
#check city 'Roskilde'
df.loc['Roskilde']
# Out:
#                      Temp  Pressure  WindSpeed  WindDir
# DateTime
# 1980-03-01 10:50:00   5.0       NaN       11.3    280.0
# 1980-03-01 12:50:00   5.0       NaN       13.3    280.0
# 1980-03-01 13:50:00   6.0       NaN       12.3    270.0
# 1980-03-01 15:50:00   4.0       NaN       12.3    270.0
# 1980-03-01 16:50:00   3.0       NaN       12.3    270.0
# ...                   ...       ...        ...      ...
# 2018-03-01 22:20:00  -5.0       NaN        5.1     70.0
# 2018-03-01 22:50:00  -5.0       NaN        4.1     70.0
# 2018-03-01 23:00:00  -5.3    1018.6        4.1     60.0
# 2018-03-01 23:20:00  -5.0       NaN        3.6     60.0
# 2018-03-01 23:50:00  -5.0       NaN        3.6     60.0
#
# [569852 rows x 4 columns]

# %%
## check column
df.columns
# Out:
# Index(['Temp', 'Pressure', 'WindSpeed', 'WindDir'], dtype='object')

# %% [markdown]
# ## 2.2 - Interacting with a server to query a subset of some data bank
#
# We will now learn how to query a data bank to retrieve only the relevant proportion data for a task. We will be using the World Bank Data API to access World's renewable energy consumtpion data.

# %% [markdown]
# You first need to install the World Bank API. In a terminal, run the following command:
#
# ``>> pip install wbdata``

# %%
# %pip install wbdata
# Out:
# Requirement already satisfied: wbdata in /Users/zhaoleihao/anaconda3/lib/python3.7/site-packages (0.3.0)
# Requirement already satisfied: appdirs<2.0,>=1.4 in /Users/zhaoleihao/anaconda3/lib/python3.7/site-packages (from wbdata) (1.4.4)
# Requirement already satisfied: tabulate>=0.8.5 in /Users/zhaoleihao/anaconda3/lib/python3.7/site-packages (from wbdata) (0.9.0)
# Requirement already satisfied: requests>=2.0 in /Users/zhaoleihao/anaconda3/lib/python3.7/site-packages (from wbdata) (2.22.0)
# Requirement already satisfied: decorator>=4.0 in /Users/zhaoleihao/anaconda3/lib/python3.7/site-packages (from wbdata) (4.4.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/zhaoleihao/anaconda3/lib/python3.7/site-packages (from requests>=2.0->wbdata) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/zhaoleihao/anaconda3/lib/python3.7/site-packages (from requests>=2.0->wbdata) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zhaoleihao/anaconda3/lib/python3.7/site-packages (from requests>=2.0->wbdata) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/zhaoleihao/anaconda3/lib/python3.7/site-packages (from requests>=2.0->wbdata) (2.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
#@title Imports
import wbdata as wb
import datetime

# %% [markdown]
# ### - Query the World Bank
#
# * **_[TO DO]_**: Use the wbdata to retrieve renewable energy consumption data of all countries in 2015.
#
# Hint: [wbdata documentation](https://wbdata.readthedocs.io/en/stable/)

# %%
### TODO
wb.get_source()
# Out:
#   id  name
# ----  --------------------------------------------------------------------
#    1  Doing Business
#    2  World Development Indicators
#    3  Worldwide Governance Indicators
#    5  Subnational Malnutrition Database
#    6  International Debt Statistics
#   11  Africa Development Indicators
#   12  Education Statistics
#   13  Enterprise Surveys
#   14  Gender Statistics
#   15  Global Economic Monitor
#   16  Health Nutrition and Population Statistics
#   18  IDA Results Measurement System
#   19  Millennium Development Goals
#   20  Quarterly Public Sector Debt
#   22  Quarterly External Debt Statistics SDDS
#   23  Quarterly External Debt Statistics GDDS
#   25  Jobs
#   27  Global Economic Prospects
#   28  Global Financial Inclusion
#   29  The Atlas of Social Protection: Indicators of Resilience and Equity
#   30  Exporter Dynamics Database – Indicators at Country-Year Level
#   31  Country Policy and Institutional Assessment
#   32  Global Financial Development
#   33  G20 Financial Inclusion Indicators
#   34  Global Partnership for Education
#   35  Sustainable Energy for All
#   36  Statistical Capacity Indicators
#   37  LAC Equity Lab
#   38  Subnational Poverty
#   39  Health Nutrition and Population Statistics by Wealth Quintile
#   40  Population estimates and projections
#   41  Country Partnership Strategy for India (FY2013 - 17)
#   43  Adjusted Net Savings
#   45  Indonesia Database for Policy and Economic Research
#   46  Sustainable Development Goals
#   50  Subnational Population
#   54  Joint External Debt Hub
#   57  WDI Database Archives
#   58  Universal Health Coverage
#   59  Wealth Accounts
#   60  Economic Fitness
#   61  PPPs Regulatory Quality
#   62  International Comparison Program (ICP) 2011
#   63  Human Capital Index
#   64  Worldwide Bureaucracy Indicators
#   65  Health Equity and Financial Protection Indicators
#   66  Logistics Performance Index
#   67  PEFA 2011
#   68  PEFA 2016
#   69  Global Financial Inclusion and Consumer Protection Survey
#   70  Economic Fitness 2
#   71  International Comparison Program (ICP) 2005
#   73  Global Financial Inclusion and Consumer Protection Survey (Internal)
#   75  Environment, Social and Governance (ESG) Data
#   76  Remittance Prices Worldwide (Sending Countries)
#   77  Remittance Prices Worldwide (Receiving Countries)
#   78  ICP 2017
#   79  PEFA_GRPFM
#   80  Gender Disaggregated Labor Database (GDLD)
#   81  International Debt Statistics: DSSI
#   82  Global Public Procurement
#   83  Statistical Performance Indicators (SPI)
#   84  Education Policy
#   85  PEFA_2021_SNG
#   86  Global Jobs Indicators Database (JOIN)
#   87  Country Climate and Development Report (CCDR)
#   88  Food Prices for Nutrition

# %%
# 35  Sustainable Energy for All
wb.get_indicator(source=35)
# Out:
# id                              name
# ------------------------------  --------------------------------------------------------------------------
# 1.1_ACCESS.ELECTRICITY.TOT      Access to electricity (% of total population)
# 1.1_TOTAL.FINAL.ENERGY.CONSUM   Total final energy consumption (TFEC)
# 1.2_ACCESS.ELECTRICITY.RURAL    Access to electricity (% of rural population)
# 1.3_ACCESS.ELECTRICITY.URBAN    Access to electricity (% of urban population)
# 2.1_ACCESS.CFT.TOT              Access to Clean Fuels and Technologies for cooking (% of total population)
# 2.1_SHARE.TOTAL.RE.IN.TFEC      Renewable energy consumption(% in TFEC)
# 3.1_RE.CONSUMPTION              Renewable energy consumption (TJ)
# 4.1.1_TOTAL.ELECTRICITY.OUTPUT  Total electricity output (GWh)
# 4.1.2_REN.ELECTRICITY.OUTPUT    Renewable energy electricity output (GWh)
# 4.1_SHARE.RE.IN.ELECTRICITY     Renewable electricity (% in total electricity output)
# 6.1_PRIMARY.ENERGY.INTENSITY    Energy intensity level of primary energy (MJ/$2005 PPP)

# %%
# id = 3.1_RE.CONSUMPTION              Renewable energy consumption (TJ)
## 返回全世界可持续资源消耗的结果 结果为json数据
wb.get_data('3.1_RE.CONSUMPTION', country='all')
# Out:
# [{'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '2016',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 112.7886,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '2014',
#   'value': 112.5079,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '2013',
#   'value': 100.653,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '2012',
#   'value': 89.68408,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '2011',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '2010',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '2009',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '2008',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '2007',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '2006',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '2005',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '2004',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '2003',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '2002',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '2001',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '2000',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '1999',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '1998',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '1997',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '1996',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '1995',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '1994',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '1993',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '1992',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '1991',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '1990',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '2016',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0.32988,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '2014',
#   'value': 0.333466,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '2013',
#   'value': 0.324444,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '2012',
#   'value': 0.325063,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '2011',
#   'value': 0.324156,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '2010',
#   'value': 0.324956,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '2009',
#   'value': 0.324507,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '2008',
#   'value': 0.321231,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '2007',
#   'value': 0.322388,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '2006',
#   'value': 0.311707,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '2005',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '2004',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '2003',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '2002',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '2001',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '2000',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '1999',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '1998',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '1997',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '1996',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '1995',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '1994',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '1993',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '1992',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '1991',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '1990',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '2016',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 16.63123,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '2014',
#   'value': 16.63128,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '2013',
#   'value': 16.61944,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '2012',
#   'value': 16.61231,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '2011',
#   'value': 16.62563,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '2010',
#   'value': 16.62032,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '2009',
#   'value': 16.40764,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '2008',
#   'value': 16.40764,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '2007',
#   'value': 16.39582,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '2006',
#   'value': 16.39582,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '2005',
#   'value': 0.39582,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '2004',
#   'value': 0.39582,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '2003',
#   'value': 0.39582,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '2002',
#   'value': 0.3544,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '2001',
#   'value': 0.34258,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '2000',
#   'value': 0.34258,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '1999',
#   'value': 0.34258,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '1998',
#   'value': 0.34258,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '1997',
#   'value': 0.33076,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '1996',
#   'value': 0.33076,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '1995',
#   'value': 0.33076,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '1994',
#   'value': 0.33076,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '1993',
#   'value': 0.33076,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '1992',
#   'value': 1.08644,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '1991',
#   'value': 0.33076,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '1990',
#   'value': 0.33076,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '2016',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '2014',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '2013',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '2012',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '2011',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '2010',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '2009',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '2008',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '2007',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '2006',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '2005',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '2004',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '2003',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '2002',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '2001',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '2000',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '1999',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '1998',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '1997',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '1996',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '1995',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '1994',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '1993',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '1992',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '1991',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '1990',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '2016',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '2014',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '2013',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '2012',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '2011',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '2010',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '2009',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '2008',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '2007',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '2006',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '2005',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '2004',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '2003',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '2002',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '2001',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '2000',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '1999',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '1998',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '1997',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '1996',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '1995',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '1994',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '1993',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '1992',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '1991',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '1990',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '2016',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '2014',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '2013',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '2012',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '2011',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '2010',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '2009',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '2008',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '2007',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '2006',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '2005',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '2004',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '2003',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '2002',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '2001',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '2000',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '1999',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '1998',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '1997',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '1996',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '1995',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '1994',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '1993',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '1992',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '1991',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '1990',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '2016',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '2014',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '2013',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '2012',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '2011',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '2010',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '2009',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '2008',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '2007',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '2006',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '2005',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '2004',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '2003',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '2002',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '2001',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '2000',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '1999',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '1998',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '1997',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '1996',
#   'value': None,
# ...
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AGO', 'value': 'Angola'},
#   'countryiso3code': '',
#   'date': '1996',
#   'value': 154657.1,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AGO', 'value': 'Angola'},
#   'countryiso3code': '',
#   'date': '1995',
#   'value': 151321.8,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AGO', 'value': 'Angola'},
#   'countryiso3code': '',
#   'date': '1994',
#   'value': 148133.8,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AGO', 'value': 'Angola'},
#   'countryiso3code': '',
#   'date': '1993',
#   'value': 145325,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AGO', 'value': 'Angola'},
#   'countryiso3code': '',
#   'date': '1992',
#   'value': 141949.7,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AGO', 'value': 'Angola'},
#   'countryiso3code': '',
#   'date': '1991',
#   'value': 138583,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AGO', 'value': 'Angola'},
#   'countryiso3code': '',
#   'date': '1990',
#   'value': 135443.7,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '2016',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '2014',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '2013',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '2012',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '2011',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '2010',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '2009',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '2008',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '2007',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '2006',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '2005',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '2004',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '2003',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '2002',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '2001',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '2000',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '1999',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '1998',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '1997',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '1996',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '1995',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '1994',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '1993',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '1992',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '1991',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '1990',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '2016',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '2014',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '2013',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '2012',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '2011',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '2010',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '2009',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '2008',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '2007',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '2006',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '2005',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '2004',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '2003',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '2002',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '2001',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '2000',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '1999',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '1998',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '1997',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '1996',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '1995',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '1994',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '1993',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '1992',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '1991',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '1990',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ARG', 'value': 'Argentina'},
#   'countryiso3code': '',
#   'date': '2016',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  ...]

# %%
## retrieve renewable energy consumption data of all countries in 2015
data_date = datetime.datetime(2015,1,1)
wb.get_data('3.1_RE.CONSUMPTION', country='all', data_date= data_date)
# Out:
# [{'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 112.7886,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0.32988,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 16.63123,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEA', 'value': 'Eastern Asia (not including Japan)'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEE', 'value': 'Eastern Europe'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEU', 'value': 'Europe'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'HIC', 'value': 'High income'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NOC', 'value': 'High income: nonOECD'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'OEC', 'value': 'High income: OECD'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GLC', 'value': 'Latin America and Caribbean'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'LMY', 'value': 'Low & middle income'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'LIC', 'value': 'Low income'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'LMC', 'value': 'Lower middle income'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MIC', 'value': 'Middle income'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GNA', 'value': 'Northern America'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'LNX', 'value': 'Not classified'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NAR', 'value': 'Nothern America'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GCN', 'value': 'Oceania'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GOC',
#    'value': 'Oceania (not including Australia and New Zealand)'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GSE', 'value': 'South Eastern Asia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GSA', 'value': 'Southern Asia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GSS', 'value': 'Sub-Saharan Africa'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'UMC', 'value': 'Upper middle income'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GWA', 'value': 'Western Asia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GWL', 'value': 'World'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AFG', 'value': 'Afghanistan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 25134.53,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ALB', 'value': 'Albania'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 31555.45,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'DZA', 'value': 'Algeria'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 833.6698,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ASM', 'value': 'American Samoa'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 4.968064,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AND', 'value': 'Andorra'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1642.52,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AGO', 'value': 'Angola'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 243771.1,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1.827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ARG', 'value': 'Argentina'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 239470.6,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ARM', 'value': 'Armenia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 13445.59,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ABW', 'value': 'Aruba'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 437.772,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AUS', 'value': 'Australia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 296838.1,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AUT', 'value': 'Austria'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 362355.8,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'AZE', 'value': 'Azerbaijan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 7681.284,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BHS', 'value': 'Bahamas, The'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 310.333,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BHR', 'value': 'Bahrain'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BGD', 'value': 'Bangladesh'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 386058.6,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BRB', 'value': 'Barbados'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 315.0794,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BLR', 'value': 'Belarus'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 44549.43,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BEL', 'value': 'Belgium'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 128345.2,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BLZ', 'value': 'Belize'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 4279.87,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BEN', 'value': 'Benin'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 76473.18,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BMU', 'value': 'Bermuda'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 123.3681,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BTN', 'value': 'Bhutan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 54615.38,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BOL', 'value': 'Bolivia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 48839.15,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BIH', 'value': 'Bosnia and Herzegovina'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 73353.16,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BWA', 'value': 'Botswana'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 23155.78,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BRA', 'value': 'Brazil'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 3887176,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'VGB', 'value': 'British Virgin Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 18.58448,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BRN', 'value': 'Brunei Darussalam'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 5.814209,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BGR', 'value': 'Bulgaria'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 69034.96,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BFA', 'value': 'Burkina Faso'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 108923.9,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'BDI', 'value': 'Burundi'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 49456.45,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'KHM', 'value': 'Cambodia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 159807,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CMR', 'value': 'Cameroon'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 217574.9,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CAN', 'value': 'Canada'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1587094,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CPV', 'value': 'Cape Verde'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1727.543,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CYM', 'value': 'Cayman Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CAF', 'value': 'Central African Republic'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 13517.51,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'TCD', 'value': 'Chad'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 59316.84,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CHI', 'value': 'Channel Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CHL', 'value': 'Chile'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 259606.8,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CHN', 'value': 'China'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 9084482,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'COL', 'value': 'Colombia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 251833.9,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'COM', 'value': 'Comoros'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1607.804,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'COD', 'value': 'Congo, Dem. Rep.'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 862513.8,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'COG', 'value': 'Congo, Rep.'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 53145.05,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'COK', 'value': 'Cook Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CRI', 'value': 'Costa Rica'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 58767.05,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CIV', 'value': "Cote d'Ivoire"},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 182270.8,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'HRV', 'value': 'Croatia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 89589.79,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CUB', 'value': 'Cuba'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 57732.18,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CUW', 'value': 'Curacao'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 85.94772,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CYP', 'value': 'Cyprus'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 5857.732,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CZE', 'value': 'Czech Republic'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 142773.3,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'DNK', 'value': 'Denmark'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 181410.8,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'DJI', 'value': 'Djibouti'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 760.8995,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'DMA', 'value': 'Dominica'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 117.062,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'DOM', 'value': 'Dominican Republic'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 37352.98,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ECU', 'value': 'Ecuador'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 68348.95,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'EGY', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 119103.6,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SLV', 'value': 'El Salvador'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 25172.23,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GNQ', 'value': 'Equatorial Guinea'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 5277.3,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ERI', 'value': 'Eritrea'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 18744.96,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'EST', 'value': 'Estonia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 31570.59,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ETH', 'value': 'Ethiopia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1574274,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'FRO', 'value': 'Faeroe Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 623.2519,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'FLK', 'value': 'Falkland Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 26.28797,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'FJI', 'value': 'Fiji'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 7491.43,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'FIN', 'value': 'Finland'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 418361.2,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'FRA', 'value': 'France'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 760300.4,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GUF', 'value': 'French Guyana'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 2928.832,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'PYF', 'value': 'French Polynesia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 766.2069,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GAB', 'value': 'Gabon'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 162175.4,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GMB', 'value': 'Gambia, The'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 5257.01,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GEO', 'value': 'Georgia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 45194.73,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'DEU', 'value': 'Germany'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1183042,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GHA', 'value': 'Ghana'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 117256,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GIB', 'value': 'Gibraltar'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GRC', 'value': 'Greece'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 112744.2,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GRL', 'value': 'Greenland'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1239.809,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GRD', 'value': 'Grenada'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 314.0524,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GLP', 'value': 'Guadeloupe'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 869.1707,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GUM', 'value': 'Guam'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GTM', 'value': 'Guatemala'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 273673.4,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GIN', 'value': 'Guinea'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 105240.5,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GNB', 'value': 'Guinea-Bissau'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 23673.55,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GUY', 'value': 'Guyana'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 6723.647,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'HTI', 'value': 'Haiti'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 103983.6,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'HND', 'value': 'Honduras'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 102277.9,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'HKG', 'value': 'Hong Kong SAR, China'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 3173.745,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'HUN', 'value': 'Hungary'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 110073.3,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ISL', 'value': 'Iceland'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 91392.87,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'IND', 'value': 'India'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 8011645,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'IDN', 'value': 'Indonesia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 2402254,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'IRN', 'value': 'Iran, Islamic Rep.'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 59942.46,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'IRQ', 'value': 'Iraq'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 5867.225,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'IRL', 'value': 'Ireland'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 39051.66,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'IMN', 'value': 'Isle of Man'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 95.54174,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ISR', 'value': 'Israel'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 18987.48,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ITA', 'value': 'Italy'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 778697.1,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'JAM', 'value': 'Jamaica'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 13776.31,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'JPN', 'value': 'Japan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 664986.9,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'JOR', 'value': 'Jordan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 7400.644,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'KAZ', 'value': 'Kazakhstan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 24725.24,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'KEN', 'value': 'Kenya'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 475941.6,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'KIR', 'value': 'Kiribati'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 25.75203,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'PRK', 'value': 'Korea, Dem. Rep.'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 63731.34,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'KOR', 'value': 'Korea, Rep.'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 143837.9,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'XKX', 'value': 'Kosovo'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 11421.65,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'KWT', 'value': 'Kuwait'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'KGZ', 'value': 'Kyrgyz Republic'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 32594.68,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'LAO', 'value': 'Lao PDR'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 72479.65,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'LVA', 'value': 'Latvia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 58759.11,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'LBN', 'value': 'Lebanon'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 7378.814,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'LSO', 'value': 'Lesotho'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 29038.03,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'LBR', 'value': 'Liberia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 68916.25,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'LBY', 'value': 'Libya'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 6350.789,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'LIE', 'value': 'Liechtenstein'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1814.258,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'LTU', 'value': 'Lithuania'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 57858.64,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'LUX', 'value': 'Luxembourg'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 13392.29,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MAC', 'value': 'Macao SAR, China'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 2406.327,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MKD', 'value': 'Macedonia, FYR'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 18886.42,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MDG', 'value': 'Madagascar'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 91950.46,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MWI', 'value': 'Malawi'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 50722.96,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MYS', 'value': 'Malaysia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 99297.57,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MDV', 'value': 'Maldives'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 160.2282,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MLI', 'value': 'Mali'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 47816.79,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MLT', 'value': 'Malta'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1026.089,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MHL', 'value': 'Marshall Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 185.6301,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MTQ', 'value': 'Martinique'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 438.3959,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MRT', 'value': 'Mauritania'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 13415.19,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MUS', 'value': 'Mauritius'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 3862.124,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MYT', 'value': 'Mayotte'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 332.8133,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MEX', 'value': 'Mexico'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 441721.1,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'FSM', 'value': 'Micronesia, Fed. Sts.'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 19.75967,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MDA', 'value': 'Moldova'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 13722.13,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MCO', 'value': 'Monaco'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MNG', 'value': 'Mongolia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 4468.379,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MNE', 'value': 'Montenegro'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 11910.79,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MSR', 'value': 'Montserrat'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MAR', 'value': 'Morocco'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 68360.09,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MOZ', 'value': 'Mozambique'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 376700.5,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MMR', 'value': 'Myanmar'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 449993.5,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NAM', 'value': 'Namibia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 18868.63,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NPL', 'value': 'Nepal'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 412327.7,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NLD', 'value': 'Netherlands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 107380.2,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ANT', 'value': 'Netherlands Antilles'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NCL', 'value': 'New Caledonia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1586.183,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NZL', 'value': 'New Zealand'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 163270.9,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NIC', 'value': 'Nicaragua'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 50040.28,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NER', 'value': 'Niger'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 89828.49,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NGA', 'value': 'Nigeria'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 4320767,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MNP', 'value': 'Northern Mariana Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'NOR', 'value': 'Norway'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 436883.3,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'OMN', 'value': 'Oman'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
# ...
#   'value': 211769.1,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'RUS', 'value': 'Russian Federation'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 522370.1,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'RWA', 'value': 'Rwanda'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 68929.6,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SPM', 'value': 'Saint Pierre et Miquelon'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 8.298344,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'WSM', 'value': 'Samoa'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1423.329,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SMR', 'value': 'San Marino'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'STP', 'value': 'Sao Tome and Principe'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 802.6961,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SAU', 'value': 'Saudi Arabia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 285.306,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SEN', 'value': 'Senegal'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 48778.32,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SRB', 'value': 'Serbia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 69936.12,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SYC', 'value': 'Seychelles'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 57.87324,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SLE', 'value': 'Sierra Leone'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 42555.34,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SGP', 'value': 'Singapore'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 3115.195,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SXM', 'value': 'Sint Maarten (Dutch part)'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 3.8635,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SVK', 'value': 'Slovak Republic'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 50516.66,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SVN', 'value': 'Slovenia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 40762.94,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SLB', 'value': 'Solomon Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 3214.943,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SOM', 'value': 'Somalia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 98912.04,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ZAF', 'value': 'South Africa'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 504710.1,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SSD', 'value': 'South Sudan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 6898.052,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ESP', 'value': 'Spain'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 513540.8,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'LKA', 'value': 'Sri Lanka'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 219348,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SHN', 'value': 'St. Helena'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 12.408,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'KNA', 'value': 'St. Kitts and Nevis'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 30.47271,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'LCA', 'value': 'St. Lucia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 81.31652,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'MAF', 'value': 'St. Martin (French part)'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'VCT', 'value': 'St. Vincent and the Grenadines'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 140.9913,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SDN', 'value': 'Sudan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 268611.1,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SUR', 'value': 'Suriname'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 6266.811,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SWZ', 'value': 'Swaziland'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 23521.78,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SWE', 'value': 'Sweden'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 679811.9,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'CHE', 'value': 'Switzerland'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 195365.5,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'SYR', 'value': 'Syrian Arab Republic'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1299,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'TWN', 'value': 'Taiwan, China'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 41598.43,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'TJK', 'value': 'Tajikistan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 44129.53,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'TZA', 'value': 'Tanzania'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 804531.9,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'THA', 'value': 'Thailand'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 722010.9,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'TLS', 'value': 'Timor-Leste'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 886.095,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'TGO', 'value': 'Togo'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 65965.75,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'TON', 'value': 'Tonga'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 23.7621,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'TTO', 'value': 'Trinidad and Tobago'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 488.5158,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'TUN', 'value': 'Tunisia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 39988.56,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'TUR', 'value': 'Turkey'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 485424.7,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'TKM', 'value': 'Turkmenistan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 307.981,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'TCA', 'value': 'Turks and Caicos Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 6.782585,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'TUV', 'value': 'Tuvalu'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'UGA', 'value': 'Uganda'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 471009,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'UKR', 'value': 'Ukraine'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 82440.89,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ARE', 'value': 'United Arab Emirates'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 2869.892,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'GBR', 'value': 'United Kingdom'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 429157.5,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'USA', 'value': 'United States'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 5097931,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'URY', 'value': 'Uruguay'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 107022.2,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'UZB', 'value': 'Uzbekistan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 34727.39,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'VUT', 'value': 'Vanuatu'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 873.3834,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'VEN', 'value': 'Venezuela, RB'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 195468.2,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'VNM', 'value': 'Vietnam'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 800189.5,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'VIR', 'value': 'Virgin Islands (U.S.)'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 91.50184,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'PSE', 'value': 'West Bank and Gaza'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 6701.55,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ESH', 'value': 'Western Sahara'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'YEM', 'value': 'Yemen, Rep.'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 2433.201,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ZMB', 'value': 'Zambia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 301679.8,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': '3.1_RE.CONSUMPTION',
#    'value': 'Renewable energy consumption (TJ)'},
#   'country': {'id': 'ZWE', 'value': 'Zimbabwe'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 324422.6,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0}]

# %% [markdown]
# ### - Undestanding the data
#
# * **_[TO DO]_**: Display different data points

# %%
### TODO

# %% [markdown]
# ### - Exporting the data
#
# * **_[TO DO]_**: Save the retrieved renewable energy consumption data of all countries in 2015 in one .xlsx file
# * **_[TO DO]_**: Save the renewable energy consumption data from 2006 to 2016 for each European country in individual .csv files (one per country)

# %%
### TODO
# renewable_dataframe = wb.get_dataframe('3.1_RE.CONSUMPTION', country='all', data_date= data_date)
# renewable_dataframe
indicators = {"3.1_RE.CONSUMPTION":"renewable energy consumption"}
renewable_dataframe = wb.get_dataframe(indicators, country ='all', data_date = data_date)
renewable_dataframe
# renewable_dataframe.to_excel("weather-data/consumption.xlsx")
# Out:
#                   renewable energy consumption
# country     date
# BES Islands 2016                           NaN
#             2015                     112.78860
#             2014                     112.50790
#             2013                     100.65300
#             2012                      89.68408
# ...                                        ...
# Zimbabwe    2010                  292578.10000
#             2009                  288035.20000
#             2008                  283868.30000
#             2007                  282020.90000
#             2006                  279849.90000
#
# [2849 rows x 1 columns]

# %%
## Save the renewable energy consumption data from 2006 to 2016 for each European country in individual .csv files (one per country)

indicators = {"3.1_RE.CONSUMPTION":"renewable energy consumption"}
data_date = datetime.datetime(2006,1,1),datetime.datetime(2016,1,1)
Europea_countries = ['Finland','Sweden','Norway','Iceland','Denmark','Faroe Islands','Estonia','Latvia','Lithuania','Moldova','Belarus','Russia','Ukraine','Poland','Czech','Slovakia','Hungary','Germany''Austria','Switzerland','Liechtenstein','United Kingdom','Ireland','Netherlands','Belgium','Luxembourg','France','Monaco','Romania','Bulgaria','Serbia','Macedonia',
'Slovenia','Croatia','Montenegro','Bosniaand','Herzegovina','Albania','Greece','Italy','Malta','Vatican City','San Marino','Spain','Portugal','Andorra','Gibraltar']
n=1
Europea_id = []
for country in Europea_countries:
    dict = wb.search_countries(country)
    if dict:
        id = Europea_id.append(dict[0]['id'])
print(Europea_id)
# print(len(Europea_id))
# print(n)
for id in Europea_id:
    country_cosump = wb.get_dataframe(indicators, country = id, data_date = data_date)
    country_cosump.to_csv(f"weather-data/{id}.csv")
# Out:
# ['FIN', 'SWE', 'NOR', 'ISL', 'DNK', 'FRO', 'EST', 'LVA', 'LTU', 'MDA', 'BLR', 'RUS', 'UKR', 'POL', 'CZE', 'HUN', 'CHE', 'LIE', 'GBR', 'IRL', 'NLD', 'BEL', 'LUX', 'FRA', 'MCO', 'ROU', 'BGR', 'SRB', 'MKD', 'SVN', 'HRV', 'MNE', 'BIH', 'ALB', 'GRC', 'ITA', 'MLT', 'SMR', 'ESP', 'PRT', 'AND', 'GIB']
# 43
